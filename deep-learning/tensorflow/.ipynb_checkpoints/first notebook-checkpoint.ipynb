# %%
val = 1500
val
# Out:
# 1500

# %% [markdown]
# # Markdown!
# with this markdown we can leave a message between code lines.
# ## Objectives
# - use Jupyter Nootebook
# - visualize the result of codes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.arange(-20, 20, 0.1)
y = np.sin(x)
plt.plot(x, y)
